# %% [markdown]
# ## Importing Packages

# %%
import matplotlib.pyplot as plt
import matplotlib.image as imread
import numpy as np
import os
from scipy.spatial import distance

# %% [markdown]
# ## Loading Files from Dataset

# %%
train_img_folder = 'training_image/'
test_img_folder = 'testing_image/'

train_files = os.listdir(train_img_folder)
test_files = os.listdir(test_img_folder)

width = 128
height = 128

# %% [markdown]
# ## Printing Training Sample Images

# %%
print("Training Images: ")
train_image_names = os.listdir(train_img_folder)
plt.figure(figsize=(10,10))
training_array = np.ndarray(shape=(len(train_image_names), height*width), dtype = np.float64)
for i in range(40):
    img = plt.imread(train_img_folder + train_image_names[i])
    training_array[i,:] = np.array(img, dtype='float64').flatten()
    plt.subplot(8,5,i+1)
    plt.imshow(img,cmap = 'gray')
# Out:
# Training Images:

# %% [markdown]
# ## Printing Testing Sample Images

# %%
print("Testing Images: ")
test_image_names = os.listdir(test_img_folder)
plt.figure(figsize=(10,10))
testing_array = np.ndarray(shape=(len(test_image_names), height*width), dtype = np.float64)
for i in range(40):
    img = plt.imread(test_img_folder + test_image_names[i])
    testing_array[i,:] = np.array(img, dtype='float64').flatten()
    plt.subplot(8,5,i+1)
    plt.imshow(img,cmap = 'gray')
# Out:
# Testing Images:

# %% [markdown]
# ## Generating Mean Face

# %%
mean_face = np.zeros((1, width*height))
for i in training_array:
    mean_face = np.add(mean_face,i)
mean_face = np.divide(mean_face,float(len(train_image_names))).flatten()
plt.imshow(mean_face.reshape(height,width), cmap = 'gray')
plt.show()

# %% [markdown]
# ## Performing Mean Zero Operation

# %%
updated_training_array = np.ndarray(shape=(len(train_image_names), height*width))
#print(updated_training_array.shape)
#print(mean_face.shape)
for i in range(len(train_image_names)):
    updated_training_array[i] = np.subtract(training_array[i],mean_face)
#print(updated_training_array[0].shape)
plt.figure(figsize=(10,10))
for i in range(40):
    img = updated_training_array[i].reshape(height,width)
    plt.subplot(8,5,i+1)
    plt.imshow(img,cmap='gray')
plt.show()

# %% [markdown]
# ## Calculating Covariance Matrix

# %%
cov_mat = np.cov(updated_training_array)
cov_mat = np.divide(cov_mat,240.0)
print(cov_mat.shape)
print(cov_mat)
# Out:
# (240, 240)
# [[ 1.32001134e-04  1.01417795e-04  4.63524448e-05 ... -1.01172183e-05
#   -1.01172183e-05 -1.01172183e-05]
#  [ 1.01417795e-04  1.76671806e-04  5.28774036e-05 ... -1.10902800e-05
#   -1.10902800e-05 -1.10902800e-05]
#  [ 4.63524448e-05  5.28774036e-05  1.05883660e-04 ... -6.36264977e-06
#   -6.36264977e-06 -6.36264977e-06]
#  ...
#  [-1.01172183e-05 -1.10902800e-05 -6.36264977e-06 ...  1.66046346e-06
#    1.66046346e-06  1.66046346e-06]
#  [-1.01172183e-05 -1.10902800e-05 -6.36264977e-06 ...  1.66046346e-06
#    1.66046346e-06  1.66046346e-06]
#  [-1.01172183e-05 -1.10902800e-05 -6.36264977e-06 ...  1.66046346e-06
#    1.66046346e-06  1.66046346e-06]]

# %% [markdown]
# ## Calculating Eigen Values and Eigen Vectors

# %%
eVal, eVec = np.linalg.eig(cov_mat)
eVal = np.real(eVal)
eVec = np.real(eVec)
# print(eVal)
# print(eVec)

# %% [markdown]
# ## Sorting Eigen Values and Eigen Vectors

# %%
eig_com = [(eVal[index], eVec[index]) for index in range(len(eVal))]

#eig_com.sort(reverse = True)

eVal_sort = [eig_com[index][0] for index in range(len(eVal))]
eVec_sort = [eig_com[index][1] for index in range(len(eVal))]

sort_index = sorted(range(eVal.shape[0]), key = lambda k: eVal[k], reverse = True)

eVal_sort = eVal[sort_index]
eVec_sort = eVec[sort_index]

#print(eVec_sort)
train_files_sort = np.array(train_files)[sort_index]

# %% [markdown]
# ## Reducing Eigen Vectors

# %%
reduced = np.array(eVec_sort[:240]).transpose()
reduced.shape
# Out:
# (240, 240)

# %%
print(training_array.transpose().shape, reduced.shape)
# Out:
# (16384, 240) (240, 240)

# %%
projected_data = np.dot(training_array.transpose(), reduced)
projected_data = (projected_data.transpose())
projected_data.shape
# Out:
# (240, 16384)

# %% [markdown]
# ## Printing Eigen Faces

# %%
plt.figure(figsize=(10,10))
for i in range(40):
    img = projected_data[i].reshape(height,width)
    plt.subplot(8,5,i+1)
    plt.imshow(img, cmap = 'gray')
plt.show()
print(projected_data.shape)
# Out:
# (240, 16384)

# %% [markdown]
# ## Generating Output

# %%
trainArr = []
testArr = []
training_array = np.array(training_array)
#print(training_array)
testing_array = np.array(testing_array)
#print(testing_array)
#print((testing_array).shape)
#training_arr_1 = training_array[:]
for i in range(1,160):
    d = []
    for j in range(1,240):
        d.append(distance.euclidean(testing_array[i], projected_data[j]))
    idx = d.index(min(d))
    #print(d)
    testArr.append(i)
    trainArr.append(idx)
    print("Test Image: " + str(i) + " ---> Matches with ---> Train Image: " +str(idx))
# Out:
# Test Image: 1 ---> Matches with ---> Train Image: 6
# Test Image: 2 ---> Matches with ---> Train Image: 26
# Test Image: 3 ---> Matches with ---> Train Image: 3
# Test Image: 4 ---> Matches with ---> Train Image: 26
# Test Image: 5 ---> Matches with ---> Train Image: 7
# Test Image: 6 ---> Matches with ---> Train Image: 15
# Test Image: 7 ---> Matches with ---> Train Image: 26
# Test Image: 8 ---> Matches with ---> Train Image: 26
# Test Image: 9 ---> Matches with ---> Train Image: 15
# Test Image: 10 ---> Matches with ---> Train Image: 15
# Test Image: 11 ---> Matches with ---> Train Image: 7
# Test Image: 12 ---> Matches with ---> Train Image: 17
# Test Image: 13 ---> Matches with ---> Train Image: 26
# Test Image: 14 ---> Matches with ---> Train Image: 17
# Test Image: 15 ---> Matches with ---> Train Image: 26
# Test Image: 16 ---> Matches with ---> Train Image: 7
# Test Image: 17 ---> Matches with ---> Train Image: 26
# Test Image: 18 ---> Matches with ---> Train Image: 3
# Test Image: 19 ---> Matches with ---> Train Image: 3
# Test Image: 20 ---> Matches with ---> Train Image: 7
# Test Image: 21 ---> Matches with ---> Train Image: 15
# Test Image: 22 ---> Matches with ---> Train Image: 26
# Test Image: 23 ---> Matches with ---> Train Image: 7
# Test Image: 24 ---> Matches with ---> Train Image: 26
# Test Image: 25 ---> Matches with ---> Train Image: 15
# Test Image: 26 ---> Matches with ---> Train Image: 6
# Test Image: 27 ---> Matches with ---> Train Image: 26
# Test Image: 28 ---> Matches with ---> Train Image: 3
# Test Image: 29 ---> Matches with ---> Train Image: 17
# Test Image: 30 ---> Matches with ---> Train Image: 26
# Test Image: 31 ---> Matches with ---> Train Image: 3
# Test Image: 32 ---> Matches with ---> Train Image: 3
# Test Image: 33 ---> Matches with ---> Train Image: 15
# Test Image: 34 ---> Matches with ---> Train Image: 15
# Test Image: 35 ---> Matches with ---> Train Image: 3
# Test Image: 36 ---> Matches with ---> Train Image: 26
# Test Image: 37 ---> Matches with ---> Train Image: 6
# Test Image: 38 ---> Matches with ---> Train Image: 15
# Test Image: 39 ---> Matches with ---> Train Image: 3
# Test Image: 40 ---> Matches with ---> Train Image: 32
# Test Image: 41 ---> Matches with ---> Train Image: 32
# Test Image: 42 ---> Matches with ---> Train Image: 32
# Test Image: 43 ---> Matches with ---> Train Image: 26
# Test Image: 44 ---> Matches with ---> Train Image: 32
# Test Image: 45 ---> Matches with ---> Train Image: 32
# Test Image: 46 ---> Matches with ---> Train Image: 42
# Test Image: 47 ---> Matches with ---> Train Image: 148
# Test Image: 48 ---> Matches with ---> Train Image: 148
# Test Image: 49 ---> Matches with ---> Train Image: 148
# Test Image: 50 ---> Matches with ---> Train Image: 148
# Test Image: 51 ---> Matches with ---> Train Image: 148
# Test Image: 52 ---> Matches with ---> Train Image: 148
# Test Image: 53 ---> Matches with ---> Train Image: 148
# Test Image: 54 ---> Matches with ---> Train Image: 148
# Test Image: 55 ---> Matches with ---> Train Image: 148
# Test Image: 56 ---> Matches with ---> Train Image: 148
# Test Image: 57 ---> Matches with ---> Train Image: 148
# Test Image: 58 ---> Matches with ---> Train Image: 148
# Test Image: 59 ---> Matches with ---> Train Image: 148
# Test Image: 60 ---> Matches with ---> Train Image: 148
# Test Image: 61 ---> Matches with ---> Train Image: 148
# Test Image: 62 ---> Matches with ---> Train Image: 148
# Test Image: 63 ---> Matches with ---> Train Image: 148
# Test Image: 64 ---> Matches with ---> Train Image: 148
# Test Image: 65 ---> Matches with ---> Train Image: 148
# Test Image: 66 ---> Matches with ---> Train Image: 148
# Test Image: 67 ---> Matches with ---> Train Image: 148
# Test Image: 68 ---> Matches with ---> Train Image: 148
# Test Image: 69 ---> Matches with ---> Train Image: 148
# Test Image: 70 ---> Matches with ---> Train Image: 148
# Test Image: 71 ---> Matches with ---> Train Image: 148
# Test Image: 72 ---> Matches with ---> Train Image: 148
# Test Image: 73 ---> Matches with ---> Train Image: 148
# Test Image: 74 ---> Matches with ---> Train Image: 148
# Test Image: 75 ---> Matches with ---> Train Image: 148
# Test Image: 76 ---> Matches with ---> Train Image: 148
# Test Image: 77 ---> Matches with ---> Train Image: 148
# Test Image: 78 ---> Matches with ---> Train Image: 148
# Test Image: 79 ---> Matches with ---> Train Image: 148
# Test Image: 80 ---> Matches with ---> Train Image: 148
# Test Image: 81 ---> Matches with ---> Train Image: 148
# Test Image: 82 ---> Matches with ---> Train Image: 148
# Test Image: 83 ---> Matches with ---> Train Image: 148
# Test Image: 84 ---> Matches with ---> Train Image: 148
# Test Image: 85 ---> Matches with ---> Train Image: 148
# Test Image: 86 ---> Matches with ---> Train Image: 148
# Test Image: 87 ---> Matches with ---> Train Image: 148
# Test Image: 88 ---> Matches with ---> Train Image: 148
# Test Image: 89 ---> Matches with ---> Train Image: 148
# Test Image: 90 ---> Matches with ---> Train Image: 148
# Test Image: 91 ---> Matches with ---> Train Image: 148
# Test Image: 92 ---> Matches with ---> Train Image: 148
# Test Image: 93 ---> Matches with ---> Train Image: 148
# Test Image: 94 ---> Matches with ---> Train Image: 148
# Test Image: 95 ---> Matches with ---> Train Image: 148
# Test Image: 96 ---> Matches with ---> Train Image: 148
# Test Image: 97 ---> Matches with ---> Train Image: 148
# Test Image: 98 ---> Matches with ---> Train Image: 148
# Test Image: 99 ---> Matches with ---> Train Image: 148
# Test Image: 100 ---> Matches with ---> Train Image: 148
# Test Image: 101 ---> Matches with ---> Train Image: 148
# Test Image: 102 ---> Matches with ---> Train Image: 148
# Test Image: 103 ---> Matches with ---> Train Image: 148
# Test Image: 104 ---> Matches with ---> Train Image: 148
# Test Image: 105 ---> Matches with ---> Train Image: 148
# Test Image: 106 ---> Matches with ---> Train Image: 148
# Test Image: 107 ---> Matches with ---> Train Image: 148
# Test Image: 108 ---> Matches with ---> Train Image: 148
# Test Image: 109 ---> Matches with ---> Train Image: 148
# Test Image: 110 ---> Matches with ---> Train Image: 148
# Test Image: 111 ---> Matches with ---> Train Image: 148
# Test Image: 112 ---> Matches with ---> Train Image: 148
# Test Image: 113 ---> Matches with ---> Train Image: 148
# Test Image: 114 ---> Matches with ---> Train Image: 148
# Test Image: 115 ---> Matches with ---> Train Image: 148
# Test Image: 116 ---> Matches with ---> Train Image: 148
# Test Image: 117 ---> Matches with ---> Train Image: 148
# Test Image: 118 ---> Matches with ---> Train Image: 148
# Test Image: 119 ---> Matches with ---> Train Image: 148
# Test Image: 120 ---> Matches with ---> Train Image: 148
# Test Image: 121 ---> Matches with ---> Train Image: 148
# Test Image: 122 ---> Matches with ---> Train Image: 148
# Test Image: 123 ---> Matches with ---> Train Image: 148
# Test Image: 124 ---> Matches with ---> Train Image: 148
# Test Image: 125 ---> Matches with ---> Train Image: 148
# Test Image: 126 ---> Matches with ---> Train Image: 148
# Test Image: 127 ---> Matches with ---> Train Image: 148
# Test Image: 128 ---> Matches with ---> Train Image: 148
# Test Image: 129 ---> Matches with ---> Train Image: 148
# Test Image: 130 ---> Matches with ---> Train Image: 148
# Test Image: 131 ---> Matches with ---> Train Image: 148
# Test Image: 132 ---> Matches with ---> Train Image: 148
# Test Image: 133 ---> Matches with ---> Train Image: 148
# Test Image: 134 ---> Matches with ---> Train Image: 148
# Test Image: 135 ---> Matches with ---> Train Image: 148
# Test Image: 136 ---> Matches with ---> Train Image: 148
# Test Image: 137 ---> Matches with ---> Train Image: 148
# Test Image: 138 ---> Matches with ---> Train Image: 148
# Test Image: 139 ---> Matches with ---> Train Image: 148
# Test Image: 140 ---> Matches with ---> Train Image: 148
# Test Image: 141 ---> Matches with ---> Train Image: 148
# Test Image: 142 ---> Matches with ---> Train Image: 148
# Test Image: 143 ---> Matches with ---> Train Image: 148
# Test Image: 144 ---> Matches with ---> Train Image: 148
# Test Image: 145 ---> Matches with ---> Train Image: 148
# Test Image: 146 ---> Matches with ---> Train Image: 148
# Test Image: 147 ---> Matches with ---> Train Image: 148
# Test Image: 148 ---> Matches with ---> Train Image: 148
# Test Image: 149 ---> Matches with ---> Train Image: 148
# Test Image: 150 ---> Matches with ---> Train Image: 148
# Test Image: 151 ---> Matches with ---> Train Image: 148
# Test Image: 152 ---> Matches with ---> Train Image: 148
# Test Image: 153 ---> Matches with ---> Train Image: 148
# Test Image: 154 ---> Matches with ---> Train Image: 148
# Test Image: 155 ---> Matches with ---> Train Image: 148
# Test Image: 156 ---> Matches with ---> Train Image: 148
# Test Image: 157 ---> Matches with ---> Train Image: 148
# Test Image: 158 ---> Matches with ---> Train Image: 148
# Test Image: 159 ---> Matches with ---> Train Image: 148

# %% [markdown]
# ## Eigen Value Mapping

# %%
eValNum = list(range(0,240))
plt.figure(figsize=(8,8))
plt.plot(eValNum, eVal)
plt.xlabel('Image Index')
plt.ylabel('Eigen Value')
plt.title('Eigen Value vs Image Indexes')
plt.legend(['Eigen Value'])
plt.show()
